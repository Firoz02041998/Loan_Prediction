# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
d = pd.read_csv("train_u6lujuX_CVtuZ9i.csv")

# %%
d
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
d.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
d2 =d.drop(['Loan_ID','Gender','Education','Property_Area','Credit_History'],axis='columns')

# %%
d2
# Out:
#     Married Dependents Self_Employed  ApplicantIncome  CoapplicantIncome  \
# 0        No          0            No             5849                0.0
# 1       Yes          1            No             4583             1508.0
# 2       Yes          0           Yes             3000                0.0
# 3       Yes          0            No             2583             2358.0
# 4        No          0            No             6000                0.0
# ..      ...        ...           ...              ...                ...
# 609      No          0            No             2900                0.0
# 610     Yes         3+            No             4106                0.0
# 611     Yes          1            No             8072              240.0
# 612     Yes          2            No             7583                0.0
# 613      No          0           Yes             4583                0.0
#
#      LoanAmount  Loan_Amount_Term Loan_Status
# ...

# %%
d2['Married_num'] = d2['Married'].replace({'No':0,'Yes':1})

# %%
d2
# Out:
#     Married Dependents Self_Employed  ApplicantIncome  CoapplicantIncome  \
# 0        No          0            No             5849                0.0
# 1       Yes          1            No             4583             1508.0
# 2       Yes          0           Yes             3000                0.0
# 3       Yes          0            No             2583             2358.0
# 4        No          0            No             6000                0.0
# ..      ...        ...           ...              ...                ...
# 609      No          0            No             2900                0.0
# 610     Yes         3+            No             4106                0.0
# 611     Yes          1            No             8072              240.0
# 612     Yes          2            No             7583                0.0
# 613      No          0           Yes             4583                0.0
#
#      LoanAmount  Loan_Amount_Term Loan_Status  Married_num
# ...

# %%
d2['SE_num'] = d2['Self_Employed'].replace({'No':0,'Yes':1})

# %%
d2
# Out:
#     Married Dependents Self_Employed  ApplicantIncome  CoapplicantIncome  \
# 0        No          0            No             5849                0.0
# 1       Yes          1            No             4583             1508.0
# 2       Yes          0           Yes             3000                0.0
# 3       Yes          0            No             2583             2358.0
# 4        No          0            No             6000                0.0
# ..      ...        ...           ...              ...                ...
# 609      No          0            No             2900                0.0
# 610     Yes         3+            No             4106                0.0
# 611     Yes          1            No             8072              240.0
# 612     Yes          2            No             7583                0.0
# 613      No          0           Yes             4583                0.0
#
#      LoanAmount  Loan_Amount_Term Loan_Status  Married_num  SE_num
# ...

# %%
d3 = d2.drop(['Married','Self_Employed'],axis='columns')

# %%
d3
# Out:
#     Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0            0             5849                0.0         NaN
# 1            1             4583             1508.0       128.0
# 2            0             3000                0.0        66.0
# 3            0             2583             2358.0       120.0
# 4            0             6000                0.0       141.0
# ..         ...              ...                ...         ...
# 609          0             2900                0.0        71.0
# 610         3+             4106                0.0        40.0
# 611          1             8072              240.0       253.0
# 612          2             7583                0.0       187.0
# 613          0             4583                0.0       133.0
#
#      Loan_Amount_Term Loan_Status  Married_num  SE_num
# 0               360.0           Y          0.0     0.0
# 1               360.0           N          1.0     0.0
# ...

# %%
d3['Loan_Status_Num'] = d3['Loan_Status'].replace({'N':0,'Y':1})

# %%
d3
# Out:
#     Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0            0             5849                0.0         NaN
# 1            1             4583             1508.0       128.0
# 2            0             3000                0.0        66.0
# 3            0             2583             2358.0       120.0
# 4            0             6000                0.0       141.0
# ..         ...              ...                ...         ...
# 609          0             2900                0.0        71.0
# 610         3+             4106                0.0        40.0
# 611          1             8072              240.0       253.0
# 612          2             7583                0.0       187.0
# 613          0             4583                0.0       133.0
#
#      Loan_Amount_Term Loan_Status  Married_num  SE_num  Loan_Status_Num
# 0               360.0           Y          0.0     0.0                1
# ...

# %%
d4 = d3.drop(['Loan_Status'],axis='columns')

# %%
d4
# Out:
#     Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0            0             5849                0.0         NaN
# 1            1             4583             1508.0       128.0
# 2            0             3000                0.0        66.0
# 3            0             2583             2358.0       120.0
# 4            0             6000                0.0       141.0
# ..         ...              ...                ...         ...
# 609          0             2900                0.0        71.0
# 610         3+             4106                0.0        40.0
# 611          1             8072              240.0       253.0
# 612          2             7583                0.0       187.0
# 613          0             4583                0.0       133.0
#
#      Loan_Amount_Term  Married_num  SE_num  Loan_Status_Num
# 0               360.0          0.0     0.0                1
# 1               360.0          1.0     0.0                0
# ...

# %%
d4.Dependents.unique()
# Out:
# array(['0', '1', '2', '3+', nan], dtype=object)

# %%
d5 = d4.fillna(0)

# %%
d5
# Out:
#     Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0            0             5849                0.0         0.0
# 1            1             4583             1508.0       128.0
# 2            0             3000                0.0        66.0
# 3            0             2583             2358.0       120.0
# 4            0             6000                0.0       141.0
# ..         ...              ...                ...         ...
# 609          0             2900                0.0        71.0
# 610         3+             4106                0.0        40.0
# 611          1             8072              240.0       253.0
# 612          2             7583                0.0       187.0
# 613          0             4583                0.0       133.0
#
#      Loan_Amount_Term  Married_num  SE_num  Loan_Status_Num
# 0               360.0          0.0     0.0                1
# 1               360.0          1.0     0.0                0
# ...

# %%
d5.isnull().sum()
# Out:
# Dependents           0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Married_num          0
# SE_num               0
# Loan_Status_Num      0
# dtype: int64

# %%
d5['Dependents_New'] = d5['Dependents'].replace(['3+'],'3')

# %%
d5
# Out:
#     Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0            0             5849                0.0         0.0
# 1            1             4583             1508.0       128.0
# 2            0             3000                0.0        66.0
# 3            0             2583             2358.0       120.0
# 4            0             6000                0.0       141.0
# ..         ...              ...                ...         ...
# 609          0             2900                0.0        71.0
# 610         3+             4106                0.0        40.0
# 611          1             8072              240.0       253.0
# 612          2             7583                0.0       187.0
# 613          0             4583                0.0       133.0
#
#      Loan_Amount_Term  Married_num  SE_num  Loan_Status_Num Dependents_New
# 0               360.0          0.0     0.0                1              0
# ...

# %%
d6 = d5.drop(['Dependents','CoapplicantIncome'],axis = 'columns')

# %%
d6
# Out:
#      ApplicantIncome  LoanAmount  Loan_Amount_Term  Married_num  SE_num  \
# 0               5849         0.0             360.0          0.0     0.0
# 1               4583       128.0             360.0          1.0     0.0
# 2               3000        66.0             360.0          1.0     1.0
# 3               2583       120.0             360.0          1.0     0.0
# 4               6000       141.0             360.0          0.0     0.0
# ..               ...         ...               ...          ...     ...
# 609             2900        71.0             360.0          0.0     0.0
# 610             4106        40.0             180.0          1.0     0.0
# 611             8072       253.0             360.0          1.0     0.0
# 612             7583       187.0             360.0          1.0     0.0
# 613             4583       133.0             360.0          0.0     1.0
#
#      Loan_Status_Num Dependents_New
# 0                  1              0
# ...

# %%
y = d6['Loan_Status_Num']

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status_Num, Length: 614, dtype: int64

# %%
d7 = d6.drop(['Loan_Status_Num'],axis = 'columns')

# %%
d7
# Out:
#      ApplicantIncome  LoanAmount  Loan_Amount_Term  Married_num  SE_num  \
# 0               5849         0.0             360.0          0.0     0.0
# 1               4583       128.0             360.0          1.0     0.0
# 2               3000        66.0             360.0          1.0     1.0
# 3               2583       120.0             360.0          1.0     0.0
# 4               6000       141.0             360.0          0.0     0.0
# ..               ...         ...               ...          ...     ...
# 609             2900        71.0             360.0          0.0     0.0
# 610             4106        40.0             180.0          1.0     0.0
# 611             8072       253.0             360.0          1.0     0.0
# 612             7583       187.0             360.0          1.0     0.0
# 613             4583       133.0             360.0          0.0     1.0
#
#     Dependents_New
# 0                0
# 1                1
# 2                0
# 3                0
# ...

# %%
from sklearn import linear_model

# %%
reg = linear_model.LinearRegression()
reg.fit(d7[['ApplicantIncome','LoanAmount','Loan_Amount_Term','Married_num','SE_num','Dependents_New']],y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.predict([[4583,128.0,360.0,1.0,0.0,1]])
# Out:
# array([0.7214382])

# %%
from sklearn.model_selection import train_test_split
X_train , X_test, y_train, y_test = train_test_split(d7,y,test_size=0.2)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB
model = GaussianNB()
model.fit(X_train,y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
model.score(X_test,y_test)
# Out:
# 0.7154471544715447
